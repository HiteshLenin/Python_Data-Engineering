# %%
#Modules
#A module is a Python file that contains functions, classes, or variables you can reuse.
# random Module
import random

print(random.randint(1, 10))
# Out:
# 4

# %%
#Choice   # list, tuple, strings # Choice picks from a sequence
import random

colors = ["red", "blue", "green"]
print(random.choice(colors))
# Out:
# red

# %%
print(random.choice("Hitesh"))
# Out:
# H

# %%
#datetime
import datetime
now = datetime.datetime.now()
print(now)
# Out:
# 2026-02-19 19:48:54.841516

# %%
#datetime (module)
 ├── date (class)
 ├── time (class)
 ├── timedelta (class)
 └── datetime (class)

# %%
today = datetime.date.today()
print(today)
# Out:
# 2026-02-19

# %%
try:
    # code that may cause error
except:
    # code runs if error occurs

# %%
#try & Except
try:
    x = 10 / 0
    print(x)
except:
     print("error occured")
# Out:
# error occured

# %%
try:
    x = int("abc")
    print(x)
except:
    print("error here")
# Out:
# error here

# %%
try:
    x = int(input("Enter number: "))
    print(10 / x)
except valueerror:
    print("Enter a valid number: ")
except zerodivisonerror:
    print("Cannot divide by zero")
# Out:
# Enter number:  25
# 0.4

# %%
try:
    f = open("data.txt")
except FileNotFoundError:
    print("File not found")
finally:
    print("Execution completed")
# Out:
# File not found
# Execution completed

# %%
try:
    print(10 / 0)
except ZeroDivisionError:
    print("Error")
else:
    print("Success")
# Out:
# Error

# %%
# File Operations
#File operations allow Python programs to:
#Write data to files
#Read data from files
#Store data permanently
#Basic File Workflow
#Open file → Perform operation (read/write) → Close file
with open(r"C:\Users\hites\OneDrive\Desktop\Data Engineer Classes\Python-Jupyter_Notebooks\Python Notes\Text_file_practice.txt", "r") as file:
    data = file.read()
    print(data)

# %%
file
# Out:
# <_io.TextIOWrapper name='C:\\Users\\hites\\OneDrive\\Desktop\\Data Engineer Classes\\Python-Jupyter_Notebooks\\Python Notes\\Text_file_practice.txt' mode='r' encoding='cp1252'>

# %%
print()

# %%
with open(r"C:\Users\hites\OneDrive\Desktop\Data Engineer Classes\Python-Jupyter_Notebooks\Python Notes\Text_file_practice.txt", "w") as file:
    file.write("Hello Hitesh\nFile handling is working")

# %%
with open(r"C:\Users\hites\OneDrive\Desktop\Data Engineer Classes\Python-Jupyter_Notebooks\Python Notes\Text_file_practice.txt", "r") as file:
    print(file.read())
# Out:
# Hello Hitesh
# File handling is working

# %%
#seek()
#seek-initialize starting point(stars from 0 basically)
#index
# seek brings data based on index number

# %%
with open(r"C:\Users\hites\OneDrive\Desktop\Data Engineer Classes\Python-Jupyter_Notebooks\Python Notes\Text_file_practice.txt", "r") as file:
    file.seek(6)
    print(file.read())
# Out:
# Hitesh
# File handling is working

# %%
#Pandas
#reads structured files (CSV, Excel, XML, JSON)
#stores them as tables
#allows easy transformation
#writes them back to files
import pandas as pd

# %%
df = pd.read_excel(
    "C:/Users/hites/OneDrive/Desktop/Data Engineer Classes/Python-Jupyter_Notebooks/Python Notes/pandastest.xlsx"
)

# %%
print(df.head())
# Out:
#      Name  Age
# 0  Hitesh   26
# 1   Lenin   27
# 2    Mike   41
# 3    Lucy   23
# 4    Mary   45

# %%
df.info() #Column data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     7 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 244.0+ bytes

# %%
df.to_excel("students.xlsx", index=False) # Load save the data aftwr making transformations

# %%
#Database connectivity
#SQLite is the simplest database to learn database connectivity because:
#No server needed
#Database is stored as a local file
#Built into Python (sqlite3 module)
#A database file is created locally using connect(), SQL commands are executed using a cursor, and changes are saved using commit().

import sqlite3

# %%
#cursor
#Cursor is used to execute SQL commands
#Think of it as a remote control for the database
#You cannot run SQL directly on the database file
#You must use a cursor
db = conn.cursor()

# %%
#commit()
#Saves changes permanently
