# %%
# Tuples--they are immutable i.e. they cannot be changed.
#Ordered
t = (1,5,8,9)

# %%
type(t)
# Out:
# tuple

# %%
d = ('hi', 77, 88,'bye')

# %%
d[1]
# Out:
# 77

# %%
d[::-1]
# Out:
# ('bye', 88, 77, 'hi')

# %%
f = (1,55,6,7,3)

# %%
f.index(3)  # Indexing
# Out:
# 4

# %%
f.count(3)  # Count
# Out:
# 1

# %%
x = (2,8,79,55)
print(type(x))
tem_list = list(x)
tem_list.append(4)
print(type(tem_list))
print(tem_list)
x = tuple(tem_list)
print(x)
# Out:
# <class 'tuple'>
# <class 'list'>
# [2, 8, 79, 55, 4]
# (2, 8, 79, 55, 4)

# %%
#Tuples are immutable--

# %%
## SETS ##

# %%
#No duplicates
#Unordered (no indexing, no slicing)
#Mutable (you can add/remove elements)
#Elements must be hashable (no lists, dicts, sets inside a set

# %%
x = set()

# %%
type(x)
# Out:
# set

# %%
x.add(25)

# %%
x
# Out:
# {25}

# %%
x.update([55,78,99,55,66])

# %%
x
# Out:
# {25, 55, 66, 78, 99}

# %%
p = {1,2,3,4,6,7}
p.remove(1)

# %%
p
# Out:
# {2, 3, 4, 6, 7}

# %%
p.discard(5)   ##safe removal even if element is not present

# %%
p
# Out:
# {2, 3, 4, 6, 7}

# %%
p.clear()

# %%
p
# Out:
# set()

# %%
i = {1,5,45,8,9,3,5,7}
i.pop()
# Out:
# 1

# %%
i
# Out:
# {3, 5, 7, 8, 9, 45}

# %%
# Dictionaries
#A dictionary (dict) stores data as key–value pairs.
#Ordered
#Mutable
#keys Unique
#Values- Duplicate
x = {'name' : 'hitesh', 'yes':'no', 'what' : ['where', 'how', 123]}

# %%
x
# Out:
# {'name': 'hitesh', 'yes': 'no', 'what': ['where', 'how']}

# %%
x['name']
# Out:
# 'hitesh'

# %%
x['what'][0]
# Out:
# 'where'

# %%
x['name'].upper()
# Out:
# 'HITESH'

# %%
x['what'][1].upper()
# Out:
# 'HOW'

# %%
x
# Out:
# {'name': 'hitesh', 'yes': 'no', 'what': ['where', 'how', 123]}

# %%
x = {'name' : 'hitesh', 'yes':'no', 'what' : ['where', 'how']}

# %%
#Python has a built-in method of doing a self subtraction or addition (or multiplication or division)
### Nesting with Dictionaries
g= x.keys()

# %%
g
# Out:
# dict_keys(['name', 'yes', 'what'])

# %%
type(g)
# Out:
# dict_keys

# %%
j=x.values()

# %%
j
# Out:
# dict_values(['hitesh', 'no', ['where', 'how']])

# %%
##shallow copy
import copy

user = ["Hitesh", 88715, "PA", "USA"]

shallow = copy.copy(user)

shallow[1] = 88876

print('shallow', shallow)
print(user)
# Out:
# shallow ['Hitesh', 88876, 'PA', 'USA']
# ['Hitesh', 88715, 'PA', 'USA']

# %%
#
import copy

user = [[1,2],[3,4]] 

deep = copy.deepcopy(user)

deep[0][0] = 12

print('original', original)
print('Deep', deep)
# Out:
# original [[1, 2], [3, 4]]
# Deep [[12, 2], [3, 4]]
